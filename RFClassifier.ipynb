# %%
import numpy as np 	

import matplotlib.pyplot as plt

import pandas as pd

# %%
dataset = pd.read_csv(r'C:\Users\Dell\Downloads\loan_data.csv')

# %%
dataset
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset['person_gender'] = le.fit_transform(dataset['person_gender'])
dataset['person_education'] = le.fit_transform(dataset['person_education'])
dataset['person_home_ownership'] = le.fit_transform(dataset['person_home_ownership'])
dataset['loan_intent'] = le.fit_transform(dataset['loan_intent'])
dataset['previous_loan_defaults_on_file'] = le.fit_transform(dataset['previous_loan_defaults_on_file'])

# %%
dataset
# Out:
#        person_age  person_gender  person_education  person_income  \
# 0            22.0              0                 4        71948.0
# 1            21.0              0                 3        12282.0
# 2            25.0              0                 3        12438.0
# 3            23.0              0                 1        79753.0
# 4            24.0              1                 4        66135.0
# ...           ...            ...               ...            ...
# 44995        27.0              1                 0        47971.0
# 44996        37.0              0                 0        65800.0
# 44997        33.0              1                 0        56942.0
# 44998        29.0              1                 1        33164.0
# 44999        24.0              1                 3        51609.0
#
#        person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# 0                   0                      3    35000.0            4
# ...

# %%
df = pd.read_excel(r"C:\Users\Dell\cleandataset.xlsx")

# %%
df
# Out:
#        person_age  person_gender  person_education  person_income  \
# 0              22              0                 4          71948
# 1              21              0                 3          12282
# 2              25              0                 3          12438
# 3              23              0                 1          79753
# 4              24              1                 4          66135
# ...           ...            ...               ...            ...
# 44995          27              1                 0          47971
# 44996          37              0                 0          65800
# 44997          33              1                 0          56942
# 44998          29              1                 1          33164
# 44999          24              1                 3          51609
#
#        person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# 0                   0                      3      35000            4
# ...

# %%
X = df.drop('loan_status',axis = 1)
y = df['loan_status']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.2, random_state=True)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# Create the model
model = RandomForestClassifier(random_state=True)  # You can also add kernel='linear' if needed

# Train the model
model.fit(X_train, y_train)

# Predictions
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

# Evaluation
print("Train Accuracy:", accuracy_score(y_train, y_pred_train))

cv_score = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean()
print("Cross-Validation Score:", cv_score)

print("Test Accuracy:", accuracy_score(y_test, y_pred_test))
# Out:
# Train Accuracy: 1.0
# Cross-Validation Score: 0.9156666666666666
# Test Accuracy: 0.9195833333333333

# %%
# %%timeit
model.fit(X_train, y_train)
# Out:
# 2.74 s ± 77 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
